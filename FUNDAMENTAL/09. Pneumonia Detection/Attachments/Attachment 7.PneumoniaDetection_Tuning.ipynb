# %% [markdown]
# ## Exploration 9. Pneumonia Diagnosis Performance Improvement 🩺

# %% [markdown]
# ### Checking the degree of model performance improvement by Fine-Tuning

# %% [markdown]
# * Control the learning speed through fine-tuning.
# * Through `callbacks.ModelCheckpoint`, the model that makes the best verification score is saved and predictions are made on the test data.

# %% [markdown]
# ### 1. Experiment Environment Set-up

# %% [markdown]
# ### 1.1 Import Libraries

# %%
import os, re
import random, math
import keras
import seaborn as sns
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### 1.2 Create Variable

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*' # *은 모든 디렉토리와 파일을 의미한다.
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

BATCH_SIZE = 16
EPOCHS = 100

print(ROOT_PATH)
# Out:
# /aiffel/aiffel

# %% [markdown]
# ### 2. Load and View Data

# %% [markdown]
# ### 2.2 Load Data

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

# %% [markdown]
# ### 2.3 Data Explorations

# %%
print('The number of train set :',len(train_filenames))
print('The number of test set :',len(test_filenames))
print('The number of validation set :',len(val_filenames))
# Out:
# The number of train set : 5216
# The number of test set : 624
# The number of validation set : 16

# %%
# train 데이터와 validation 데이터를 모두 filenames에 담는다. 
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눈다.
train_size = math.floor(len(filenames)*0.85)
random.seed(8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print('The number of train set :',len(train_filenames))
print('The number of validation set :',len(val_filenames))
# Out:
# The number of train set : 4447
# The number of validation set : 785

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")


COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1140
# Pneumonia images count in training set: 3307

# %%
# tf.data 인스턴스 만들기
# tf.data는 tensorflow에서 학습시킬 때, mini-batch로 작업할 수 있도록 해준다.
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
# train data set 개수 확인
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

# validation data set 개수 확인
VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4447
# Validating images count: 785

# %%
# 현재 이미지에는 라벨 데이터가 따로 없는 상태
# 파일 경로에 'NORMAL'이나 'PNEUMONIA'가 포함
# 이를 이용해 라벨 데이터를 만들어 주는 함수 생성

# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %%
# 이미지 데이터는 현실적으로 사이즈가 제각각일 가능성이 높다.
# 이미지의 사이즈를 줄임과 동시에 통일시켜준다.

# 이미지를 알맞은 형식으로 바꾼다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어온다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %%
# train data, validation data set 만들기
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
# data 변환 여부 확인하기
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %%
# test data set에도 위와 동일하게 적용
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
# tf.data 파이프라인을 이용하여 prepare_for_training() 함수 정의
# shuffle() : 고정 크기 버퍼를 유지하고 해당 버퍼에서 무작위로 균일하게 다음 요소를 선택
# repeat() : epoch를 진행하면서 여러 번 데이터셋을 불러오게 되는데, 이때 repeat()를 사용한 데이터셋의 경우 여러 번 사용 가능
# batch() : BATCH_SIZE에서 정한 만큼의 배치로 주어짐
# prefetch() : 학습 데이터를 나눠서 읽어옴. 첫 번째 데이터가 GPU에서 학습하는 동안 두 번째 데이터를 CPU에서 준비. 리소스의 유휴 상태를 줄일 수 있음.

def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# ### 2.4 Data Visualization

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(4,math.ceil(BATCH_SIZE/4),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# ### 3. Create and Train a Model

# %% [markdown]
# ### 3.1 CNN Modeling (Normalization, Dropout)

# %%
# Convolution block
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
# Dense Block
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# ### 3.2 Data Imbalance Handling

# %%
# weight_for_0은 'Normal' 이미지에 사용할 weight 세팅
# weight_for_1은 'Pneumonia' 이미지에 사용할 weight 세팅
# 이 weight들은 'Normal'과 'Pneumonia' 전체 데이터 건수에 반비례하도록 설정

weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.95
# Weight for PNEUMONIA: 0.67

# %% [markdown]
# ### 3.3 Train a Model (Fine-tuning)

# %%
# 미지의 라벨이 두 개밖에 없기 때문에 "binary_cross entropy" loss 사용
# optimizer로 'adam' 사용
# 성과에 대해서 측정하기 위한 metrics으로 'accuracy', 'precision', 'recall'사용

with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
# callback으로 훈련 중 가장 최상의 점수를 낸 모델 저장
# 매개변수 restore_best_weights를 True로 지정하여 가장 낮은 검증 손실을 낸 모델 파라미터로 되돌린다.
es = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
cb = tf.keras.callbacks.ModelCheckpoint('tuning_model.h5', save_best_only = True)

# %%
# 학습속도 조절
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 20)

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %%
history = model.fit(
    train_ds,
    steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
    epochs=100,
    validation_data=val_ds,
    validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
    class_weight=class_weight,
    callbacks=[cb, es, lr_scheduler]
)
# Out:
# Epoch 1/100
# 277/277 [==============================] - 91s 186ms/step - loss: 0.4394 - accuracy: 0.7990 - precision: 0.9212 - recall: 0.7979 - val_loss: 1.5645 - val_accuracy: 0.7372 - val_precision: 0.7393 - val_recall: 0.9913
# Epoch 2/100
# 277/277 [==============================] - 50s 182ms/step - loss: 0.2675 - accuracy: 0.8910 - precision: 0.9631 - recall: 0.8874 - val_loss: 0.2015 - val_accuracy: 0.9298 - val_precision: 0.9797 - val_recall: 0.9235
# Epoch 3/100
# 277/277 [==============================] - 51s 183ms/step - loss: 0.2286 - accuracy: 0.9082 - precision: 0.9710 - recall: 0.9036 - val_loss: 10.6817 - val_accuracy: 0.7347 - val_precision: 0.7347 - val_recall: 1.0000
# Epoch 4/100
# 277/277 [==============================] - 50s 182ms/step - loss: 0.2329 - accuracy: 0.9023 - precision: 0.9701 - recall: 0.8961 - val_loss: 0.1752 - val_accuracy: 0.9196 - val_precision: 0.9923 - val_recall: 0.8976
# Epoch 5/100
# 277/277 [==============================] - 52s 187ms/step - loss: 0.2112 - accuracy: 0.9086 - precision: 0.9762 - recall: 0.8988 - val_loss: 0.1492 - val_accuracy: 0.9452 - val_precision: 0.9963 - val_recall: 0.9287
# Epoch 6/100
# 277/277 [==============================] - 53s 193ms/step - loss: 0.2311 - accuracy: 0.9084 - precision: 0.9695 - recall: 0.9056 - val_loss: 0.4038 - val_accuracy: 0.8827 - val_precision: 0.8756 - val_recall: 0.9791
# Epoch 7/100
# 277/277 [==============================] - 48s 172ms/step - loss: 0.1789 - accuracy: 0.9273 - precision: 0.9809 - recall: 0.9200 - val_loss: 0.1675 - val_accuracy: 0.9464 - val_precision: 0.9362 - val_recall: 0.9948
# Epoch 8/100
# 277/277 [==============================] - 47s 172ms/step - loss: 0.1850 - accuracy: 0.9255 - precision: 0.9799 - recall: 0.9187 - val_loss: 20.8455 - val_accuracy: 0.7334 - val_precision: 0.7334 - val_recall: 1.0000
# Epoch 9/100
# 277/277 [==============================] - 47s 171ms/step - loss: 0.1831 - accuracy: 0.9244 - precision: 0.9809 - recall: 0.9164 - val_loss: 0.1543 - val_accuracy: 0.9464 - val_precision: 0.9981 - val_recall: 0.9287
# Epoch 10/100
# 277/277 [==============================] - 47s 171ms/step - loss: 0.1375 - accuracy: 0.9454 - precision: 0.9863 - recall: 0.9396 - val_loss: 0.6668 - val_accuracy: 0.7589 - val_precision: 0.7526 - val_recall: 1.0000
# Epoch 11/100
# 277/277 [==============================] - 49s 176ms/step - loss: 0.1349 - accuracy: 0.9449 - precision: 0.9851 - recall: 0.9403 - val_loss: 0.0886 - val_accuracy: 0.9668 - val_precision: 0.9964 - val_recall: 0.9583
# Epoch 12/100
# 277/277 [==============================] - 49s 177ms/step - loss: 0.1243 - accuracy: 0.9535 - precision: 0.9880 - recall: 0.9491 - val_loss: 0.0953 - val_accuracy: 0.9566 - val_precision: 0.9927 - val_recall: 0.9479
# Epoch 13/100
# 277/277 [==============================] - 48s 172ms/step - loss: 0.1122 - accuracy: 0.9544 - precision: 0.9874 - recall: 0.9507 - val_loss: 0.1121 - val_accuracy: 0.9566 - val_precision: 0.9822 - val_recall: 0.9583
# Epoch 14/100
# 277/277 [==============================] - 50s 179ms/step - loss: 0.1155 - accuracy: 0.9592 - precision: 0.9899 - recall: 0.9548 - val_loss: 0.1720 - val_accuracy: 0.9286 - val_precision: 0.9962 - val_recall: 0.9061
# Epoch 15/100
# 277/277 [==============================] - 49s 178ms/step - loss: 0.0946 - accuracy: 0.9650 - precision: 0.9906 - recall: 0.9621 - val_loss: 0.0988 - val_accuracy: 0.9605 - val_precision: 0.9910 - val_recall: 0.9548
# Epoch 16/100
# 277/277 [==============================] - 50s 180ms/step - loss: 0.1067 - accuracy: 0.9657 - precision: 0.9891 - recall: 0.9646 - val_loss: 0.0642 - val_accuracy: 0.9745 - val_precision: 0.9929 - val_recall: 0.9722
# Epoch 17/100
# 277/277 [==============================] - 48s 174ms/step - loss: 0.0724 - accuracy: 0.9752 - precision: 0.9956 - recall: 0.9708 - val_loss: 0.0623 - val_accuracy: 0.9707 - val_precision: 0.9859 - val_recall: 0.9740
# Epoch 18/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.0833 - accuracy: 0.9743 - precision: 0.9932 - recall: 0.9721 - val_loss: 0.0666 - val_accuracy: 0.9796 - val_precision: 0.9947 - val_recall: 0.9774
# Epoch 19/100
# 277/277 [==============================] - 49s 177ms/step - loss: 0.0838 - accuracy: 0.9743 - precision: 0.9947 - recall: 0.9707 - val_loss: 0.0725 - val_accuracy: 0.9770 - val_precision: 0.9982 - val_recall: 0.9704
# Epoch 20/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.0668 - accuracy: 0.9754 - precision: 0.9950 - recall: 0.9718 - val_loss: 0.0575 - val_accuracy: 0.9745 - val_precision: 0.9894 - val_recall: 0.9757
# Epoch 21/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.0644 - accuracy: 0.9752 - precision: 0.9950 - recall: 0.9715 - val_loss: 0.0695 - val_accuracy: 0.9783 - val_precision: 0.9964 - val_recall: 0.9739
# Epoch 22/100
# 277/277 [==============================] - 47s 171ms/step - loss: 0.0619 - accuracy: 0.9788 - precision: 0.9960 - recall: 0.9755 - val_loss: 0.0602 - val_accuracy: 0.9770 - val_precision: 0.9912 - val_recall: 0.9774
# Epoch 23/100
# 277/277 [==============================] - 48s 173ms/step - loss: 0.0587 - accuracy: 0.9781 - precision: 0.9944 - recall: 0.9760 - val_loss: 0.0937 - val_accuracy: 0.9643 - val_precision: 0.9910 - val_recall: 0.9600
# Epoch 24/100
# 277/277 [==============================] - 46s 168ms/step - loss: 0.0519 - accuracy: 0.9831 - precision: 0.9960 - recall: 0.9811 - val_loss: 0.0597 - val_accuracy: 0.9758 - val_precision: 0.9826 - val_recall: 0.9843
# Epoch 25/100
# 277/277 [==============================] - 48s 172ms/step - loss: 0.0492 - accuracy: 0.9822 - precision: 0.9945 - recall: 0.9815 - val_loss: 0.0551 - val_accuracy: 0.9796 - val_precision: 0.9878 - val_recall: 0.9844
# Epoch 26/100
# 277/277 [==============================] - 46s 167ms/step - loss: 0.0490 - accuracy: 0.9840 - precision: 0.9957 - recall: 0.9826 - val_loss: 0.0675 - val_accuracy: 0.9758 - val_precision: 0.9827 - val_recall: 0.9844
# Epoch 27/100
# 277/277 [==============================] - 46s 168ms/step - loss: 0.0403 - accuracy: 0.9878 - precision: 0.9976 - recall: 0.9862 - val_loss: 0.0604 - val_accuracy: 0.9796 - val_precision: 0.9895 - val_recall: 0.9826
# Epoch 28/100
# 277/277 [==============================] - 48s 174ms/step - loss: 0.0469 - accuracy: 0.9862 - precision: 0.9963 - recall: 0.9851 - val_loss: 0.0634 - val_accuracy: 0.9732 - val_precision: 0.9826 - val_recall: 0.9809
# Epoch 29/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.0407 - accuracy: 0.9869 - precision: 0.9957 - recall: 0.9866 - val_loss: 0.0678 - val_accuracy: 0.9758 - val_precision: 0.9810 - val_recall: 0.9861
# Epoch 30/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.0396 - accuracy: 0.9905 - precision: 0.9982 - recall: 0.9891 - val_loss: 0.0769 - val_accuracy: 0.9694 - val_precision: 0.9859 - val_recall: 0.9722
# Epoch 31/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.0371 - accuracy: 0.9871 - precision: 0.9972 - recall: 0.9854 - val_loss: 0.0644 - val_accuracy: 0.9783 - val_precision: 0.9912 - val_recall: 0.9791
# Epoch 32/100
# 277/277 [==============================] - 46s 168ms/step - loss: 0.0387 - accuracy: 0.9880 - precision: 0.9975 - recall: 0.9864 - val_loss: 0.0716 - val_accuracy: 0.9745 - val_precision: 0.9894 - val_recall: 0.9757
# Epoch 33/100
# 277/277 [==============================] - 47s 169ms/step - loss: 0.0332 - accuracy: 0.9901 - precision: 0.9982 - recall: 0.9884 - val_loss: 0.0638 - val_accuracy: 0.9758 - val_precision: 0.9843 - val_recall: 0.9826
# Epoch 34/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.0355 - accuracy: 0.9887 - precision: 0.9972 - recall: 0.9875 - val_loss: 0.0665 - val_accuracy: 0.9758 - val_precision: 0.9810 - val_recall: 0.9861
# Epoch 35/100
# 277/277 [==============================] - 47s 171ms/step - loss: 0.0306 - accuracy: 0.9903 - precision: 0.9988 - recall: 0.9882 - val_loss: 0.0669 - val_accuracy: 0.9745 - val_precision: 0.9826 - val_recall: 0.9826

# %% [markdown]
# ### 3.4 Interpret the results

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ### 4. Prediction Using Trained Model

# %%
best_model = keras.models.load_model('tuning_model.h5')

# %%
loss, accuracy, precision, recall = best_model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 39/39 [==============================] - 4s 106ms/step - loss: 1.1582 - accuracy: 0.7885 - precision: 0.7529 - recall: 0.9846
# Loss: 1.1582111120224,
# Accuracy: 0.7884615659713745,
# Precision: 0.7529411911964417,
# Recall: 0.9846153855323792
