# %% [markdown]
# ## Exploration 9. Pneumonia Diagnosis Performance Improvement 🩺

# %% [markdown]
# ### Checking the degree of model performance improvement by Data Augmentation

# %% [markdown]
# * The angle of the picture is randomly tilted by 30 degrees.
# * Through `callbacks.ModelCheckpoint`, the model that makes the best verification score is saved and predictions are made on the test data.

# %% [markdown]
# ### 1. Experiment Environment Set-up

# %% [markdown]
# ### 1.1 Import Libraries

# %%
import os, re
import random, math
import keras
import seaborn as sns
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### 1.2 Create Variable

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*' # *은 모든 디렉토리와 파일을 의미한다.
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

BATCH_SIZE = 16
EPOCHS = 100

print(ROOT_PATH)
# Out:
# /aiffel/aiffel

# %% [markdown]
# ### 2. Load and View Data

# %% [markdown]
# ### 2.2 Load Data

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

# %% [markdown]
# ### 2.3 Data Explorations

# %%
print('The number of train set :',len(train_filenames))
print('The number of test set :',len(test_filenames))
print('The number of validation set :',len(val_filenames))
# Out:
# The number of train set : 5216
# The number of test set : 624
# The number of validation set : 16

# %%
# train 데이터와 validation 데이터를 모두 filenames에 담는다. 
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눈다.
train_size = math.floor(len(filenames)*0.85)
random.seed(8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print('The number of train set :',len(train_filenames))
print('The number of validation set :',len(val_filenames))
# Out:
# The number of train set : 4447
# The number of validation set : 785

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")


COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1140
# Pneumonia images count in training set: 3307

# %%
# tf.data 인스턴스 만들기
# tf.data는 tensorflow에서 학습시킬 때, mini-batch로 작업할 수 있도록 해준다.
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
# train data set 개수 확인
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

# validation data set 개수 확인
VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4447
# Validating images count: 785

# %%
# 현재 이미지에는 라벨 데이터가 따로 없는 상태
# 파일 경로에 'NORMAL'이나 'PNEUMONIA'가 포함
# 이를 이용해 라벨 데이터를 만들어 주는 함수 생성

# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %%
# 이미지 데이터는 현실적으로 사이즈가 제각각일 가능성이 높다.
# 이미지의 사이즈를 줄임과 동시에 통일시켜준다.

# 이미지를 알맞은 형식으로 바꾼다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어온다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %%
# train data, validation data set 만들기
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
# data 변환 여부 확인하기
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %%
# test data set에도 위와 동일하게 적용
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
# tf.data 파이프라인을 이용하여 prepare_for_training() 함수 정의
# shuffle() : 고정 크기 버퍼를 유지하고 해당 버퍼에서 무작위로 균일하게 다음 요소를 선택
# repeat() : epoch를 진행하면서 여러 번 데이터셋을 불러오게 되는데, 이때 repeat()를 사용한 데이터셋의 경우 여러 번 사용 가능
# batch() : BATCH_SIZE에서 정한 만큼의 배치로 주어짐
# prefetch() : 학습 데이터를 나눠서 읽어옴. 첫 번째 데이터가 GPU에서 학습하는 동안 두 번째 데이터를 CPU에서 준비. 리소스의 유휴 상태를 줄일 수 있음.

def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# ### 2.4 Data Visualization

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(4,math.ceil(BATCH_SIZE/4),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# ### 3. Create and Train a Model

# %% [markdown]
# ### 3.1 CNN Modeling (Normalization, Dropout)

# %%
# Convolution block
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
# Dense Block
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Sequential([tf.keras.layers.experimental.preprocessing.RandomRotation(0.3)]),  # layer를 통해 이미지 회전
        
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# ### 3.2 Data Imbalance Handling

# %%
# weight_for_0은 'Normal' 이미지에 사용할 weight 세팅
# weight_for_1은 'Pneumonia' 이미지에 사용할 weight 세팅
# 이 weight들은 'Normal'과 'Pneumonia' 전체 데이터 건수에 반비례하도록 설정

weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.95
# Weight for PNEUMONIA: 0.67

# %% [markdown]
# ### 3.3 Train a Model

# %%
# 미지의 라벨이 두 개밖에 없기 때문에 "binary_cross entropy" loss 사용
# optimizer로 'adam' 사용
# 성과에 대해서 측정하기 위한 metrics으로 'accuracy', 'precision', 'recall'사용

with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
# callback으로 훈련 중 가장 최상의 점수를 낸 모델 저장
# earlystopping으로 3번 연속 검증 점수가 향상되지 않을 때 훈련 중지
# 매개변수 restore_best_weights를 True로 지정하여 가장 낮은 검증 손실을 낸 모델 파라미터로 되돌린다.

cb = tf.keras.callbacks.ModelCheckpoint('augmentation_model.h5', save_best_only = True)

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
        callbacks=[cb]
    )
# Out:
# Epoch 1/100
# 277/277 [==============================] - 63s 179ms/step - loss: 0.4933 - accuracy: 0.7615 - precision: 0.9315 - recall: 0.7335 - val_loss: 0.6583 - val_accuracy: 0.7347 - val_precision: 0.7347 - val_recall: 1.0000
# Epoch 2/100
# 277/277 [==============================] - 50s 182ms/step - loss: 0.3656 - accuracy: 0.8362 - precision: 0.9518 - recall: 0.8213 - val_loss: 1.2771 - val_accuracy: 0.7347 - val_precision: 0.7347 - val_recall: 1.0000
# Epoch 3/100
# 277/277 [==============================] - 50s 179ms/step - loss: 0.3337 - accuracy: 0.8567 - precision: 0.9612 - recall: 0.8414 - val_loss: 0.2863 - val_accuracy: 0.8469 - val_precision: 0.8311 - val_recall: 0.9930
# Epoch 4/100
# 277/277 [==============================] - 50s 182ms/step - loss: 0.2903 - accuracy: 0.8793 - precision: 0.9636 - recall: 0.8702 - val_loss: 0.6426 - val_accuracy: 0.8023 - val_precision: 0.9930 - val_recall: 0.7357
# Epoch 5/100
# 277/277 [==============================] - 51s 186ms/step - loss: 0.2896 - accuracy: 0.8818 - precision: 0.9648 - recall: 0.8729 - val_loss: 0.9197 - val_accuracy: 0.7398 - val_precision: 0.7381 - val_recall: 1.0000
# Epoch 6/100
# 277/277 [==============================] - 53s 192ms/step - loss: 0.2810 - accuracy: 0.8779 - precision: 0.9653 - recall: 0.8673 - val_loss: 0.8388 - val_accuracy: 0.7615 - val_precision: 0.9974 - val_recall: 0.6765
# Epoch 7/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.2560 - accuracy: 0.8949 - precision: 0.9723 - recall: 0.8838 - val_loss: 6.3181 - val_accuracy: 0.2666 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/100
# 277/277 [==============================] - 47s 171ms/step - loss: 0.2511 - accuracy: 0.8955 - precision: 0.9711 - recall: 0.8861 - val_loss: 0.8424 - val_accuracy: 0.7385 - val_precision: 0.9973 - val_recall: 0.6452
# Epoch 9/100
# 277/277 [==============================] - 48s 172ms/step - loss: 0.2386 - accuracy: 0.9039 - precision: 0.9747 - recall: 0.8934 - val_loss: 0.5068 - val_accuracy: 0.7717 - val_precision: 1.0000 - val_recall: 0.6887
# Epoch 10/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.2358 - accuracy: 0.9064 - precision: 0.9731 - recall: 0.8992 - val_loss: 0.3963 - val_accuracy: 0.8635 - val_precision: 0.9937 - val_recall: 0.8191
# Epoch 11/100
# 277/277 [==============================] - 47s 171ms/step - loss: 0.2348 - accuracy: 0.9064 - precision: 0.9739 - recall: 0.8977 - val_loss: 0.2014 - val_accuracy: 0.9107 - val_precision: 0.9961 - val_recall: 0.8817y - ETA: 2s - loss: 0.2424 - accuracy: 0.9051
# Epoch 12/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.2273 - accuracy: 0.9075 - precision: 0.9741 - recall: 0.8999 - val_loss: 0.3217 - val_accuracy: 0.8699 - val_precision: 0.9937 - val_recall: 0.8278
# Epoch 13/100
# 277/277 [==============================] - 46s 166ms/step - loss: 0.2066 - accuracy: 0.9131 - precision: 0.9718 - recall: 0.9095 - val_loss: 0.9645 - val_accuracy: 0.6964 - val_precision: 1.0000 - val_recall: 0.5861
# Epoch 14/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.2207 - accuracy: 0.9086 - precision: 0.9727 - recall: 0.9019 - val_loss: 1.1162 - val_accuracy: 0.5179 - val_precision: 1.0000 - val_recall: 0.3438
# Epoch 15/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.2078 - accuracy: 0.9143 - precision: 0.9809 - recall: 0.9025 - val_loss: 0.2680 - val_accuracy: 0.8916 - val_precision: 0.9940 - val_recall: 0.8576
# Epoch 16/100
# 277/277 [==============================] - 47s 171ms/step - loss: 0.2037 - accuracy: 0.9167 - precision: 0.9782 - recall: 0.9089 - val_loss: 0.2033 - val_accuracy: 0.9222 - val_precision: 0.9079 - val_recall: 0.9948
# Epoch 17/100
# 277/277 [==============================] - 47s 169ms/step - loss: 0.1953 - accuracy: 0.9222 - precision: 0.9779 - recall: 0.9156 - val_loss: 0.1120 - val_accuracy: 0.9541 - val_precision: 0.9909 - val_recall: 0.9461
# Epoch 18/100
# 277/277 [==============================] - 47s 169ms/step - loss: 0.1976 - accuracy: 0.9176 - precision: 0.9759 - recall: 0.9116 - val_loss: 0.1213 - val_accuracy: 0.9515 - val_precision: 0.9856 - val_recall: 0.9479
# Epoch 19/100
# 277/277 [==============================] - 48s 172ms/step - loss: 0.1831 - accuracy: 0.9251 - precision: 0.9812 - recall: 0.9168 - val_loss: 0.4237 - val_accuracy: 0.8520 - val_precision: 0.9957 - val_recall: 0.8017
# Epoch 20/100
# 277/277 [==============================] - 47s 169ms/step - loss: 0.2007 - accuracy: 0.9219 - precision: 0.9786 - recall: 0.9150 - val_loss: 0.8587 - val_accuracy: 0.7334 - val_precision: 1.0000 - val_recall: 0.6372
# Epoch 21/100
# 277/277 [==============================] - 46s 168ms/step - loss: 0.1942 - accuracy: 0.9204 - precision: 0.9779 - recall: 0.9136 - val_loss: 0.1545 - val_accuracy: 0.9452 - val_precision: 0.9963 - val_recall: 0.9287
# Epoch 22/100
# 277/277 [==============================] - 47s 169ms/step - loss: 0.1891 - accuracy: 0.9215 - precision: 0.9789 - recall: 0.9143 - val_loss: 0.4086 - val_accuracy: 0.8240 - val_precision: 1.0000 - val_recall: 0.7600
# Epoch 23/100
# 277/277 [==============================] - 47s 172ms/step - loss: 0.1916 - accuracy: 0.9255 - precision: 0.9802 - recall: 0.9183 - val_loss: 0.1543 - val_accuracy: 0.9426 - val_precision: 0.9963 - val_recall: 0.9252
# Epoch 24/100
# 277/277 [==============================] - 48s 174ms/step - loss: 0.1627 - accuracy: 0.9337 - precision: 0.9792 - recall: 0.9304 - val_loss: 0.0911 - val_accuracy: 0.9694 - val_precision: 0.9928 - val_recall: 0.9652
# Epoch 25/100
# 277/277 [==============================] - 47s 169ms/step - loss: 0.1741 - accuracy: 0.9321 - precision: 0.9789 - recall: 0.9287 - val_loss: 0.0923 - val_accuracy: 0.9681 - val_precision: 0.9893 - val_recall: 0.9670
# Epoch 26/100
# 277/277 [==============================] - 49s 176ms/step - loss: 0.1779 - accuracy: 0.9294 - precision: 0.9807 - recall: 0.9233 - val_loss: 0.1207 - val_accuracy: 0.9554 - val_precision: 0.9856 - val_recall: 0.9530
# Epoch 27/100
# 277/277 [==============================] - 48s 173ms/step - loss: 0.1797 - accuracy: 0.9296 - precision: 0.9788 - recall: 0.9252 - val_loss: 0.3557 - val_accuracy: 0.8750 - val_precision: 0.8544 - val_recall: 1.0000
# Epoch 28/100
# 277/277 [==============================] - 48s 173ms/step - loss: 0.1808 - accuracy: 0.9240 - precision: 0.9806 - recall: 0.9163 - val_loss: 0.1111 - val_accuracy: 0.9579 - val_precision: 0.9562 - val_recall: 0.9878
# Epoch 29/100
# 277/277 [==============================] - 48s 174ms/step - loss: 0.1717 - accuracy: 0.9382 - precision: 0.9825 - recall: 0.9337 - val_loss: 0.1376 - val_accuracy: 0.9388 - val_precision: 0.9981 - val_recall: 0.9183
# Epoch 30/100
# 277/277 [==============================] - 49s 175ms/step - loss: 0.1662 - accuracy: 0.9307 - precision: 0.9815 - recall: 0.9238 - val_loss: 0.0949 - val_accuracy: 0.9656 - val_precision: 0.9824 - val_recall: 0.9704
# Epoch 31/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.1538 - accuracy: 0.9425 - precision: 0.9833 - recall: 0.9392 - val_loss: 0.1173 - val_accuracy: 0.9554 - val_precision: 0.9892 - val_recall: 0.9497
# Epoch 32/100
# 277/277 [==============================] - 48s 172ms/step - loss: 0.1840 - accuracy: 0.9310 - precision: 0.9786 - recall: 0.9265 - val_loss: 0.0863 - val_accuracy: 0.9643 - val_precision: 0.9807 - val_recall: 0.9705
# Epoch 33/100
# 277/277 [==============================] - 46s 168ms/step - loss: 0.1549 - accuracy: 0.9440 - precision: 0.9854 - recall: 0.9388 - val_loss: 0.0771 - val_accuracy: 0.9707 - val_precision: 0.9964 - val_recall: 0.9635
# Epoch 34/100
# 277/277 [==============================] - 46s 166ms/step - loss: 0.1676 - accuracy: 0.9323 - precision: 0.9816 - recall: 0.9261 - val_loss: 0.2989 - val_accuracy: 0.8712 - val_precision: 1.0000 - val_recall: 0.8243
# Epoch 35/100
# 277/277 [==============================] - 48s 173ms/step - loss: 0.1599 - accuracy: 0.9330 - precision: 0.9858 - recall: 0.9235 - val_loss: 0.1202 - val_accuracy: 0.9477 - val_precision: 0.9855 - val_recall: 0.9426
# Epoch 36/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.1678 - accuracy: 0.9337 - precision: 0.9823 - recall: 0.9275 - val_loss: 0.0717 - val_accuracy: 0.9783 - val_precision: 0.9912 - val_recall: 0.9791
# Epoch 37/100
# 277/277 [==============================] - 46s 168ms/step - loss: 0.1418 - accuracy: 0.9445 - precision: 0.9866 - recall: 0.9381 - val_loss: 0.0979 - val_accuracy: 0.9592 - val_precision: 0.9823 - val_recall: 0.9618
# Epoch 38/100
# 277/277 [==============================] - 48s 175ms/step - loss: 0.1490 - accuracy: 0.9370 - precision: 0.9813 - recall: 0.9337 - val_loss: 0.4248 - val_accuracy: 0.7755 - val_precision: 0.9975 - val_recall: 0.6957
# Epoch 39/100
# 277/277 [==============================] - 49s 177ms/step - loss: 0.1416 - accuracy: 0.9465 - precision: 0.9866 - recall: 0.9407 - val_loss: 0.0813 - val_accuracy: 0.9719 - val_precision: 0.9894 - val_recall: 0.9722
# Epoch 40/100
# 277/277 [==============================] - 48s 174ms/step - loss: 0.1490 - accuracy: 0.9458 - precision: 0.9847 - recall: 0.9417 - val_loss: 0.0716 - val_accuracy: 0.9707 - val_precision: 0.9792 - val_recall: 0.9809
# Epoch 41/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.1458 - accuracy: 0.9422 - precision: 0.9856 - recall: 0.9357 - val_loss: 0.0676 - val_accuracy: 0.9758 - val_precision: 0.9894 - val_recall: 0.9774
# Epoch 42/100
# 277/277 [==============================] - 49s 176ms/step - loss: 0.1621 - accuracy: 0.9425 - precision: 0.9825 - recall: 0.9392 - val_loss: 0.0989 - val_accuracy: 0.9605 - val_precision: 0.9722 - val_recall: 0.9739
# Epoch 43/100
# 277/277 [==============================] - 48s 174ms/step - loss: 0.1414 - accuracy: 0.9481 - precision: 0.9852 - recall: 0.9449 - val_loss: 0.0894 - val_accuracy: 0.9681 - val_precision: 0.9859 - val_recall: 0.9704
# Epoch 44/100
# 277/277 [==============================] - 46s 168ms/step - loss: 0.1303 - accuracy: 0.9486 - precision: 0.9823 - recall: 0.9476 - val_loss: 0.0688 - val_accuracy: 0.9796 - val_precision: 0.9929 - val_recall: 0.9791
# Epoch 45/100
# 277/277 [==============================] - 47s 171ms/step - loss: 0.1586 - accuracy: 0.9409 - precision: 0.9835 - recall: 0.9367 - val_loss: 0.1885 - val_accuracy: 0.9247 - val_precision: 0.9981 - val_recall: 0.8991
# Epoch 46/100
# 277/277 [==============================] - 47s 169ms/step - loss: 0.1425 - accuracy: 0.9499 - precision: 0.9862 - recall: 0.9450 - val_loss: 0.0943 - val_accuracy: 0.9554 - val_precision: 0.9639 - val_recall: 0.9757
# Epoch 47/100
# 277/277 [==============================] - 47s 171ms/step - loss: 0.1290 - accuracy: 0.9544 - precision: 0.9863 - recall: 0.9524 - val_loss: 0.0696 - val_accuracy: 0.9758 - val_precision: 0.9947 - val_recall: 0.9722
# Epoch 48/100
# 277/277 [==============================] - 47s 171ms/step - loss: 0.1291 - accuracy: 0.9535 - precision: 0.9871 - recall: 0.9499 - val_loss: 0.0845 - val_accuracy: 0.9668 - val_precision: 0.9661 - val_recall: 0.9896
# Epoch 49/100
# 277/277 [==============================] - 47s 171ms/step - loss: 0.1273 - accuracy: 0.9560 - precision: 0.9881 - recall: 0.9525 - val_loss: 0.2694 - val_accuracy: 0.9031 - val_precision: 1.0000 - val_recall: 0.8678
# Epoch 50/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.1189 - accuracy: 0.9592 - precision: 0.9869 - recall: 0.9579 - val_loss: 0.0736 - val_accuracy: 0.9745 - val_precision: 0.9912 - val_recall: 0.9740
# Epoch 51/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.1113 - accuracy: 0.9596 - precision: 0.9874 - recall: 0.9576 - val_loss: 0.0673 - val_accuracy: 0.9783 - val_precision: 0.9878 - val_recall: 0.9826
# Epoch 52/100
# 277/277 [==============================] - 46s 168ms/step - loss: 0.1135 - accuracy: 0.9585 - precision: 0.9878 - recall: 0.9560 - val_loss: 0.0758 - val_accuracy: 0.9681 - val_precision: 0.9893 - val_recall: 0.9670
# Epoch 53/100
# 277/277 [==============================] - 47s 169ms/step - loss: 0.1229 - accuracy: 0.9549 - precision: 0.9871 - recall: 0.9518 - val_loss: 0.0733 - val_accuracy: 0.9770 - val_precision: 0.9860 - val_recall: 0.9826
# Epoch 54/100
# 277/277 [==============================] - 48s 173ms/step - loss: 0.1118 - accuracy: 0.9571 - precision: 0.9896 - recall: 0.9522 - val_loss: 0.0740 - val_accuracy: 0.9719 - val_precision: 0.9946 - val_recall: 0.9670
# Epoch 55/100
# 277/277 [==============================] - 47s 169ms/step - loss: 0.1045 - accuracy: 0.9598 - precision: 0.9900 - recall: 0.9559 - val_loss: 0.0759 - val_accuracy: 0.9707 - val_precision: 0.9662 - val_recall: 0.9948
# Epoch 56/100
# 277/277 [==============================] - 48s 175ms/step - loss: 0.1285 - accuracy: 0.9544 - precision: 0.9871 - recall: 0.9510 - val_loss: 0.1006 - val_accuracy: 0.9630 - val_precision: 0.9982 - val_recall: 0.9513
# Epoch 57/100
# 277/277 [==============================] - 48s 172ms/step - loss: 0.1044 - accuracy: 0.9619 - precision: 0.9888 - recall: 0.9597 - val_loss: 0.1483 - val_accuracy: 0.9413 - val_precision: 0.9288 - val_recall: 0.9965
# Epoch 58/100
# 277/277 [==============================] - 48s 174ms/step - loss: 0.1100 - accuracy: 0.9610 - precision: 0.9910 - recall: 0.9566 - val_loss: 0.0846 - val_accuracy: 0.9707 - val_precision: 0.9792 - val_recall: 0.9809
# Epoch 59/100
# 277/277 [==============================] - 47s 172ms/step - loss: 0.1254 - accuracy: 0.9501 - precision: 0.9866 - recall: 0.9453 - val_loss: 0.0596 - val_accuracy: 0.9796 - val_precision: 0.9912 - val_recall: 0.9809
# Epoch 60/100
# 277/277 [==============================] - 46s 167ms/step - loss: 0.1177 - accuracy: 0.9562 - precision: 0.9847 - recall: 0.9561 - val_loss: 0.2495 - val_accuracy: 0.9222 - val_precision: 0.9107 - val_recall: 0.9913
# Epoch 61/100
# 277/277 [==============================] - 48s 173ms/step - loss: 0.1203 - accuracy: 0.9551 - precision: 0.9859 - recall: 0.9533 - val_loss: 0.1435 - val_accuracy: 0.9362 - val_precision: 0.9981 - val_recall: 0.9148
# Epoch 62/100
# 277/277 [==============================] - 48s 174ms/step - loss: 0.1489 - accuracy: 0.9506 - precision: 0.9851 - recall: 0.9477 - val_loss: 0.1154 - val_accuracy: 0.9490 - val_precision: 0.9422 - val_recall: 0.9913
# Epoch 63/100
# 277/277 [==============================] - 48s 172ms/step - loss: 0.1512 - accuracy: 0.9425 - precision: 0.9835 - recall: 0.9386 - val_loss: 0.0635 - val_accuracy: 0.9834 - val_precision: 0.9930 - val_recall: 0.9843
# Epoch 64/100
# 277/277 [==============================] - 48s 172ms/step - loss: 0.1358 - accuracy: 0.9488 - precision: 0.9863 - recall: 0.9440 - val_loss: 0.0933 - val_accuracy: 0.9681 - val_precision: 0.9964 - val_recall: 0.9601
# Epoch 65/100
# 277/277 [==============================] - 48s 172ms/step - loss: 0.1203 - accuracy: 0.9580 - precision: 0.9878 - recall: 0.9554 - val_loss: 0.0782 - val_accuracy: 0.9732 - val_precision: 0.9946 - val_recall: 0.9687
# Epoch 66/100
# 277/277 [==============================] - 48s 172ms/step - loss: 0.1167 - accuracy: 0.9592 - precision: 0.9854 - recall: 0.9594 - val_loss: 0.1208 - val_accuracy: 0.9579 - val_precision: 1.0000 - val_recall: 0.9426
# Epoch 67/100
# 277/277 [==============================] - 48s 173ms/step - loss: 0.1110 - accuracy: 0.9589 - precision: 0.9881 - recall: 0.9564 - val_loss: 0.0816 - val_accuracy: 0.9707 - val_precision: 0.9742 - val_recall: 0.9861
# Epoch 68/100
# 277/277 [==============================] - 47s 171ms/step - loss: 0.1166 - accuracy: 0.9585 - precision: 0.9880 - recall: 0.9554 - val_loss: 0.1009 - val_accuracy: 0.9630 - val_precision: 0.9740 - val_recall: 0.9757
# Epoch 69/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.1264 - accuracy: 0.9519 - precision: 0.9874 - recall: 0.9476 - val_loss: 0.0838 - val_accuracy: 0.9694 - val_precision: 0.9946 - val_recall: 0.9635
# Epoch 70/100
# 277/277 [==============================] - 48s 175ms/step - loss: 0.1078 - accuracy: 0.9616 - precision: 0.9881 - recall: 0.9599 - val_loss: 0.0696 - val_accuracy: 0.9745 - val_precision: 0.9947 - val_recall: 0.9704
# Epoch 71/100
# 277/277 [==============================] - 48s 173ms/step - loss: 0.0998 - accuracy: 0.9655 - precision: 0.9901 - recall: 0.9634 - val_loss: 0.1063 - val_accuracy: 0.9694 - val_precision: 0.9775 - val_recall: 0.9809
# Epoch 72/100
# 277/277 [==============================] - 49s 175ms/step - loss: 0.1100 - accuracy: 0.9592 - precision: 0.9875 - recall: 0.9572 - val_loss: 0.0709 - val_accuracy: 0.9758 - val_precision: 0.9826 - val_recall: 0.9843
# Epoch 73/100
# 277/277 [==============================] - 48s 174ms/step - loss: 0.1039 - accuracy: 0.9653 - precision: 0.9912 - recall: 0.9616 - val_loss: 0.1323 - val_accuracy: 0.9490 - val_precision: 1.0000 - val_recall: 0.9304
# Epoch 74/100
# 277/277 [==============================] - 47s 171ms/step - loss: 0.1044 - accuracy: 0.9598 - precision: 0.9909 - recall: 0.9550 - val_loss: 0.0606 - val_accuracy: 0.9783 - val_precision: 0.9964 - val_recall: 0.9739
# Epoch 75/100
# 277/277 [==============================] - 48s 175ms/step - loss: 0.1062 - accuracy: 0.9610 - precision: 0.9881 - recall: 0.9589 - val_loss: 0.0560 - val_accuracy: 0.9809 - val_precision: 0.9930 - val_recall: 0.9809
# Epoch 76/100
# 277/277 [==============================] - 47s 171ms/step - loss: 0.1027 - accuracy: 0.9605 - precision: 0.9888 - recall: 0.9580 - val_loss: 0.0611 - val_accuracy: 0.9770 - val_precision: 0.9843 - val_recall: 0.9843
# Epoch 77/100
# 277/277 [==============================] - 48s 173ms/step - loss: 0.1100 - accuracy: 0.9607 - precision: 0.9887 - recall: 0.9581 - val_loss: 0.0861 - val_accuracy: 0.9681 - val_precision: 0.9928 - val_recall: 0.9635
# Epoch 78/100
# 277/277 [==============================] - 48s 174ms/step - loss: 0.0960 - accuracy: 0.9630 - precision: 0.9888 - recall: 0.9613 - val_loss: 0.0851 - val_accuracy: 0.9707 - val_precision: 0.9964 - val_recall: 0.9635
# Epoch 79/100
# 277/277 [==============================] - 48s 174ms/step - loss: 0.0972 - accuracy: 0.9664 - precision: 0.9911 - recall: 0.9628 - val_loss: 0.0872 - val_accuracy: 0.9668 - val_precision: 0.9928 - val_recall: 0.9617
# Epoch 80/100
# 277/277 [==============================] - 48s 172ms/step - loss: 0.1036 - accuracy: 0.9619 - precision: 0.9910 - recall: 0.9581 - val_loss: 0.0992 - val_accuracy: 0.9745 - val_precision: 0.9727 - val_recall: 0.9930
# Epoch 81/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.1073 - accuracy: 0.9630 - precision: 0.9884 - recall: 0.9612 - val_loss: 0.0788 - val_accuracy: 0.9745 - val_precision: 0.9964 - val_recall: 0.9688
# Epoch 82/100
# 277/277 [==============================] - 46s 168ms/step - loss: 0.0990 - accuracy: 0.9641 - precision: 0.9894 - recall: 0.9622 - val_loss: 0.0514 - val_accuracy: 0.9821 - val_precision: 0.9947 - val_recall: 0.9809
# Epoch 83/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.1024 - accuracy: 0.9619 - precision: 0.9881 - recall: 0.9601 - val_loss: 0.1429 - val_accuracy: 0.9452 - val_precision: 0.9981 - val_recall: 0.9270
# Epoch 84/100
# 277/277 [==============================] - 47s 171ms/step - loss: 0.0884 - accuracy: 0.9686 - precision: 0.9919 - recall: 0.9659 - val_loss: 0.0826 - val_accuracy: 0.9694 - val_precision: 0.9928 - val_recall: 0.9652
# Epoch 85/100
# 277/277 [==============================] - 47s 169ms/step - loss: 0.0956 - accuracy: 0.9639 - precision: 0.9894 - recall: 0.9619 - val_loss: 0.0588 - val_accuracy: 0.9809 - val_precision: 0.9895 - val_recall: 0.9843
# Epoch 86/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.0970 - accuracy: 0.9630 - precision: 0.9879 - recall: 0.9621 - val_loss: 0.0679 - val_accuracy: 0.9783 - val_precision: 0.9964 - val_recall: 0.9739
# Epoch 87/100
# 277/277 [==============================] - 46s 166ms/step - loss: 0.0951 - accuracy: 0.9668 - precision: 0.9912 - recall: 0.9637 - val_loss: 0.7826 - val_accuracy: 0.8316 - val_precision: 0.8133 - val_recall: 1.0000
# Epoch 88/100
# 277/277 [==============================] - 48s 172ms/step - loss: 0.1054 - accuracy: 0.9610 - precision: 0.9896 - recall: 0.9575 - val_loss: 0.0977 - val_accuracy: 0.9668 - val_precision: 0.9982 - val_recall: 0.9565
# Epoch 89/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.0902 - accuracy: 0.9700 - precision: 0.9913 - recall: 0.9681 - val_loss: 0.1755 - val_accuracy: 0.9298 - val_precision: 0.9981 - val_recall: 0.9061
# Epoch 90/100
# 277/277 [==============================] - 47s 169ms/step - loss: 0.1054 - accuracy: 0.9630 - precision: 0.9894 - recall: 0.9607 - val_loss: 0.0607 - val_accuracy: 0.9770 - val_precision: 0.9947 - val_recall: 0.9739
# Epoch 91/100
# 277/277 [==============================] - 48s 172ms/step - loss: 0.0958 - accuracy: 0.9644 - precision: 0.9894 - recall: 0.9625 - val_loss: 0.0538 - val_accuracy: 0.9821 - val_precision: 0.9845 - val_recall: 0.9913
# Epoch 92/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.0983 - accuracy: 0.9628 - precision: 0.9881 - recall: 0.9614 - val_loss: 0.1363 - val_accuracy: 0.9617 - val_precision: 0.9534 - val_recall: 0.9965
# Epoch 93/100
# 277/277 [==============================] - 49s 176ms/step - loss: 0.0974 - accuracy: 0.9650 - precision: 0.9894 - recall: 0.9632 - val_loss: 0.0611 - val_accuracy: 0.9783 - val_precision: 0.9912 - val_recall: 0.9792
# Epoch 94/100
# 277/277 [==============================] - 47s 172ms/step - loss: 0.0877 - accuracy: 0.9680 - precision: 0.9913 - recall: 0.9655 - val_loss: 0.0803 - val_accuracy: 0.9719 - val_precision: 0.9964 - val_recall: 0.9652
# Epoch 95/100
# 277/277 [==============================] - 48s 173ms/step - loss: 0.0826 - accuracy: 0.9718 - precision: 0.9925 - recall: 0.9693 - val_loss: 0.1117 - val_accuracy: 0.9541 - val_precision: 0.9945 - val_recall: 0.9426
# Epoch 96/100
# 277/277 [==============================] - 47s 170ms/step - loss: 0.1070 - accuracy: 0.9628 - precision: 0.9876 - recall: 0.9622 - val_loss: 0.0826 - val_accuracy: 0.9681 - val_precision: 0.9982 - val_recall: 0.9583
# Epoch 97/100
# 277/277 [==============================] - 48s 172ms/step - loss: 0.0873 - accuracy: 0.9695 - precision: 0.9913 - recall: 0.9675 - val_loss: 0.3057 - val_accuracy: 0.9707 - val_precision: 0.9662 - val_recall: 0.9948
# Epoch 98/100
# 277/277 [==============================] - 47s 171ms/step - loss: 0.1248 - accuracy: 0.9546 - precision: 0.9884 - recall: 0.9504 - val_loss: 0.1515 - val_accuracy: 0.9362 - val_precision: 1.0000 - val_recall: 0.9130
# Epoch 99/100
# 277/277 [==============================] - 47s 169ms/step - loss: 0.1093 - accuracy: 0.9616 - precision: 0.9887 - recall: 0.9592 - val_loss: 0.0687 - val_accuracy: 0.9758 - val_precision: 0.9877 - val_recall: 0.9791
# Epoch 100/100
# 277/277 [==============================] - 46s 168ms/step - loss: 0.0990 - accuracy: 0.9623 - precision: 0.9869 - recall: 0.9621 - val_loss: 0.1637 - val_accuracy: 0.9298 - val_precision: 0.9981 - val_recall: 0.9061

# %% [markdown]
# ### 3.4 Interpret the results

# %%
fig, ax = plt.subplots(2, 2, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ### 4. Prediction Using Trained Model

# %%
best_model = keras.models.load_model('augmentation_model.h5')

# %%
loss, accuracy, precision, recall = best_model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 39/39 [==============================] - 5s 117ms/step - loss: 0.5372 - accuracy: 0.8397 - precision: 0.7971 - recall: 0.9974
# Loss: 0.5372244715690613,
# Accuracy: 0.8397436141967773,
# Precision: 0.7971311211585999,
# Recall: 0.9974358677864075
